# %% [markdown]
# Jean has provided a list of files with the shifted filter transmissions, and modified transmissions for the bad `r` (`fluxes.fits`), and catalogs with the sources, and a column per each alteration of the `r` filter (`fluxes_COSMOS15_*.fits`).
#
# So, need to create a copy of the input catalog (\_test) adding per each of the altered column (shift0...shift9, skewed...), the mean wavelength of the filters, which can be calculated from `fluxes.fits`.
#
# With the new catalog, we should run nnpz, and get the same result with `r` not shifted and without wavelength mean, and with each of the `r_...` columns and providing the filter mean wavelength.

# %%
from astropy.io import fits
from astropy.table import Table
import numpy as np

# %%
fluxes = fits.open('/home/aalvarez/Work/Data/coupon/fluxes.fits')

# %%
fluxes.info()
# Out:
# Filename: /home/aalvarez/Work/Data/coupon/fluxes.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  NNPZ_PHOTOMETRY    1 BinTableHDU    110   518404R x 50C   [K, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]
#   2  u             1 BinTableHDU     13   1898R x 2C   [E, E]
#   3  g             1 BinTableHDU     13   799R x 2C   [E, E]
#   4  r             1 BinTableHDU     13   10000R x 2C   [E, E]
#   5  i             1 BinTableHDU     13   799R x 2C   [E, E]
#   6  z             1 BinTableHDU     13   799R x 2C   [E, E]
#   7  vis           1 BinTableHDU     13   900R x 2C   [E, E]
#   8  Y             1 BinTableHDU     13   1800R x 2C   [E, E]
#   9  J             1 BinTableHDU     13   1800R x 2C   [E, E]
#  10  H             1 BinTableHDU     13   1800R x 2C   [E, E]
#  11  r_shift0      1 BinTableHDU     13   9999R x 2C   [E, E]
#  12  r_shift1      1 BinTableHDU     13   9999R x 2C   [E, E]
#  13  r_shift2      1 BinTableHDU     13   9999R x 2C   [E, E]
#  14  r_shift3      1 BinTableHDU     13   9999R x 2C   [E, E]
#  15  r_shift4      1 BinTableHDU     13   9999R x 2C   [E, E]
#  16  r_shift5      1 BinTableHDU     13   9999R x 2C   [E, E]
#  17  r_shift6      1 BinTableHDU     13   9999R x 2C   [E, E]
#  18  r_shift7      1 BinTableHDU     13   9999R x 2C   [E, E]
#  19  r_shift8      1 BinTableHDU     13   9999R x 2C   [E, E]
#  20  r_shift9      1 BinTableHDU     13   9999R x 2C   [E, E]
#  21  r_widening0    1 BinTableHDU     13   9999R x 2C   [E, E]
#  22  r_widening1    1 BinTableHDU     13   9999R x 2C   [E, E]
#  23  r_widening2    1 BinTableHDU     13   9999R x 2C   [E, E]
#  24  r_widening3    1 BinTableHDU     13   9999R x 2C   [E, E]
#  25  r_widening4    1 BinTableHDU     13   9999R x 2C   [E, E]
#  26  r_widening5    1 BinTableHDU     13   9999R x 2C   [E, E]
#  27  r_widening6    1 BinTableHDU     13   9999R x 2C   [E, E]
#  28  r_widening7    1 BinTableHDU     13   9999R x 2C   [E, E]
#  29  r_widening8    1 BinTableHDU     13   9999R x 2C   [E, E]
#  30  r_widening9    1 BinTableHDU     13   9999R x 2C   [E, E]
#  31  r_skewing0    1 BinTableHDU     13   9999R x 2C   [E, E]
#  32  r_skewing1    1 BinTableHDU     13   9999R x 2C   [E, E]
#  33  r_skewing2    1 BinTableHDU     13   9999R x 2C   [E, E]
#  34  r_skewing3    1 BinTableHDU     13   9999R x 2C   [E, E]
#  35  r_skewing4    1 BinTableHDU     13   9999R x 2C   [E, E]
#  36  r_skewing5    1 BinTableHDU     13   9999R x 2C   [E, E]
#  37  r_skewing6    1 BinTableHDU     13   9999R x 2C   [E, E]
#  38  r_skewing7    1 BinTableHDU     13   9999R x 2C   [E, E]
#  39  r_skewing8    1 BinTableHDU     13   9999R x 2C   [E, E]
#  40  r_skewing9    1 BinTableHDU     13   9999R x 2C   [E, E]
#  41  r_softening0    1 BinTableHDU     13   9999R x 2C   [E, E]
#  42  r_softening1    1 BinTableHDU     13   9999R x 2C   [E, E]
#  43  r_softening2    1 BinTableHDU     13   9999R x 2C   [E, E]
#  44  r_softening3    1 BinTableHDU     13   9999R x 2C   [E, E]
#  45  r_softening4    1 BinTableHDU     13   9999R x 2C   [E, E]
#  46  r_softening5    1 BinTableHDU     13   9999R x 2C   [E, E]
#  47  r_softening6    1 BinTableHDU     13   9999R x 2C   [E, E]
#  48  r_softening7    1 BinTableHDU     13   9999R x 2C   [E, E]
#  49  r_softening8    1 BinTableHDU     13   9999R x 2C   [E, E]
#  50  r_softening9    1 BinTableHDU     13   9999R x 2C   [E, E]

# %%
test = fits.open('/home/aalvarez/Work/Data/coupon/fluxes_COSMOS15_test.fits')

# %%
test[1].columns
# Out:
# ColDefs(
#     name = 'ID'; format = 'K'
#     name = 'u'; format = 'E'
#     name = 'g'; format = 'E'
#     name = 'r'; format = 'E'
#     name = 'i'; format = 'E'
#     name = 'z'; format = 'E'
#     name = 'vis'; format = 'E'
#     name = 'Y'; format = 'E'
#     name = 'J'; format = 'E'
#     name = 'H'; format = 'E'
#     name = 'r_shift0'; format = 'E'
#     name = 'r_shift1'; format = 'E'
#     name = 'r_shift2'; format = 'E'
#     name = 'r_shift3'; format = 'E'
#     name = 'r_shift4'; format = 'E'
#     name = 'r_shift5'; format = 'E'
#     name = 'r_shift6'; format = 'E'
#     name = 'r_shift7'; format = 'E'
#     name = 'r_shift8'; format = 'E'
#     name = 'r_shift9'; format = 'E'
#     name = 'r_widening0'; format = 'E'
#     name = 'r_widening1'; format = 'E'
#     name = 'r_widening2'; format = 'E'
#     name = 'r_widening3'; format = 'E'
#     name = 'r_widening4'; format = 'E'
#     name = 'r_widening5'; format = 'E'
#     name = 'r_widening6'; format = 'E'
#     name = 'r_widening7'; format = 'E'
#     name = 'r_widening8'; format = 'E'
#     name = 'r_widening9'; format = 'E'
#     name = 'r_skewing0'; format = 'E'
#     name = 'r_skewing1'; format = 'E'
#     name = 'r_skewing2'; format = 'E'
#     name = 'r_skewing3'; format = 'E'
#     name = 'r_skewing4'; format = 'E'
#     name = 'r_skewing5'; format = 'E'
#     name = 'r_skewing6'; format = 'E'
#     name = 'r_skewing7'; format = 'E'
#     name = 'r_skewing8'; format = 'E'
#     name = 'r_skewing9'; format = 'E'
#     name = 'r_softening0'; format = 'E'
#     name = 'r_softening1'; format = 'E'
#     name = 'r_softening2'; format = 'E'
#     name = 'r_softening3'; format = 'E'
#     name = 'r_softening4'; format = 'E'
#     name = 'r_softening5'; format = 'E'
#     name = 'r_softening6'; format = 'E'
#     name = 'r_softening7'; format = 'E'
#     name = 'r_softening8'; format = 'E'
#     name = 'r_softening9'; format = 'E'
#     name = 'ra'; format = 'D'; unit = 'deg'
#     name = 'dec'; format = 'D'; unit = 'deg'
#     name = 'z_true'; format = 'E'
#     name = 'has_spec_z'; format = 'I'; null = -32768
#     name = 'weight'; format = 'D'
#     name = 'radius'; format = 'D'
#     name = 'r_shift7_obs_mag_err'; format = 'E'
#     name = 'r_widening8_obs_mag'; format = 'E'
#     name = 'r_skewing9_obs_err'; format = 'E'
#     name = 'r_softening1_obs_mag'; format = 'E'
#     name = 'r_softening5_obs'; format = 'E'
#     name = 'r_softening8_obs_err'; format = 'E'
#     name = 'r_skewing3_obs_mag_err'; format = 'E'
#     name = 'r_shift0_obs_mag_err'; format = 'E'
#     name = 'r_softening9_obs_err'; format = 'E'
#     name = 'r_skewing8_obs_err'; format = 'E'
#     name = 'r_shift1_obs_err'; format = 'E'
#     name = 'r_skewing0_obs'; format = 'E'
#     name = 'r_shift9_obs_err'; format = 'E'
#     name = 'r_skewing6_obs_mag'; format = 'E'
#     name = 'i_obs_mag'; format = 'E'
#     name = 'r_widening0_obs_err'; format = 'E'
#     name = 'r_softening0_obs'; format = 'E'
#     name = 'r_widening7_obs_mag'; format = 'E'
#     name = 'r_skewing5_obs_mag'; format = 'E'
#     name = 'J_obs_mag_err'; format = 'E'
#     name = 'i_obs'; format = 'E'
#     name = 'r_softening1_obs'; format = 'E'
#     name = 'r_skewing8_obs_mag'; format = 'E'
#     name = 'r_softening4_obs_mag_err'; format = 'E'
#     name = 'z_obs_mag'; format = 'E'
#     name = 'r_widening6_obs_mag_err'; format = 'E'
#     name = 'r_softening5_obs_err'; format = 'E'
#     name = 'r_skewing1_obs'; format = 'E'
#     name = 'r_shift3_obs_mag'; format = 'E'
#     name = 'r_widening8_obs_mag_err'; format = 'E'
#     name = 'r_widening3_obs_mag'; format = 'E'
#     name = 'r_widening3_obs_mag_err'; format = 'E'
#     name = 'r_skewing2_obs_err'; format = 'E'
#     name = 'r_softening4_obs_mag'; format = 'E'
#     name = 'r_widening6_obs_mag'; format = 'E'
#     name = 'r_skewing6_obs_err'; format = 'E'
#     name = 'r_softening3_obs_err'; format = 'E'
#     name = 'r_widening8_obs'; format = 'E'
#     name = 'r_skewing4_obs_mag_err'; format = 'E'
#     name = 'r_softening0_obs_mag'; format = 'E'
#     name = 'r_shift0_obs'; format = 'E'
#     name = 'Y_obs_mag'; format = 'E'
#     name = 'r_skewing5_obs_err'; format = 'E'
#     name = 'r_shift6_obs_mag_err'; format = 'E'
#     name = 'g_obs_mag'; format = 'E'
#     name = 'r_skewing1_obs_mag'; format = 'E'
#     name = 'r_softening0_obs_mag_err'; format = 'E'
#     name = 'g_obs'; format = 'E'
#     name = 'r_softening1_obs_mag_err'; format = 'E'
#     name = 'u_obs_mag_err'; format = 'E'
#     name = 'r_shift7_obs'; format = 'E'
#     name = 'r_widening4_obs_mag_err'; format = 'E'
#     name = 'i_obs_mag_err'; format = 'E'
#     name = 'r_obs'; format = 'E'
#     name = 'r_obs_err'; format = 'E'
#     name = 'r_widening0_obs_mag'; format = 'E'
#     name = 'r_widening6_obs_err'; format = 'E'
#     name = 'r_softening5_obs_mag'; format = 'E'
#     name = 'r_widening5_obs_mag'; format = 'E'
#     name = 'r_softening5_obs_mag_err'; format = 'E'
#     name = 'r_softening7_obs_err'; format = 'E'
#     name = 'r_widening5_obs_err'; format = 'E'
#     name = 'r_skewing7_obs_err'; format = 'E'
#     name = 'r_widening4_obs'; format = 'E'
#     name = 'r_softening6_obs_err'; format = 'E'
#     name = 'H_obs_mag'; format = 'E'
#     name = 'r_widening6_obs'; format = 'E'
#     name = 'g_obs_err'; format = 'E'
#     name = 'r_softening8_obs_mag_err'; format = 'E'
#     name = 'r_skewing0_obs_mag'; format = 'E'
#     name = 'r_widening5_obs_mag_err'; format = 'E'
#     name = 'r_softening2_obs_mag_err'; format = 'E'
#     name = 'H_obs_mag_err'; format = 'E'
#     name = 'r_widening9_obs'; format = 'E'
#     name = 'r_skewing1_obs_mag_err'; format = 'E'
#     name = 'r_softening6_obs_mag'; format = 'E'
#     name = 'r_skewing9_obs'; format = 'E'
#     name = 'r_shift0_obs_err'; format = 'E'
#     name = 'vis_obs_mag_err'; format = 'E'
#     name = 'r_shift5_obs_err'; format = 'E'
#     name = 'r_widening2_obs_err'; format = 'E'
#     name = 'r_widening8_obs_err'; format = 'E'
#     name = 'r_skewing8_obs_mag_err'; format = 'E'
#     name = 'r_widening3_obs'; format = 'E'
#     name = 'r_skewing6_obs_mag_err'; format = 'E'
#     name = 'r_softening9_obs'; format = 'E'
#     name = 'r_skewing3_obs_err'; format = 'E'
#     name = 'r_skewing0_obs_mag_err'; format = 'E'
#     name = 'r_shift8_obs_mag_err'; format = 'E'
#     name = 'r_widening1_obs_err'; format = 'E'
#     name = 'r_widening2_obs_mag_err'; format = 'E'
#     name = 'r_softening6_obs'; format = 'E'
#     name = 'r_widening2_obs'; format = 'E'
#     name = 'r_shift8_obs_err'; format = 'E'
#     name = 'r_widening2_obs_mag'; format = 'E'
#     name = 'r_skewing8_obs'; format = 'E'
#     name = 'r_softening3_obs_mag'; format = 'E'
#     name = 'r_skewing3_obs'; format = 'E'
#     name = 'r_shift2_obs_err'; format = 'E'
#     name = 'r_skewing7_obs'; format = 'E'
#     name = 'r_skewing7_obs_mag'; format = 'E'
#     name = 'r_softening0_obs_err'; format = 'E'
#     name = 'r_softening7_obs_mag_err'; format = 'E'
#     name = 'r_shift6_obs'; format = 'E'
#     name = 'r_softening3_obs_mag_err'; format = 'E'
#     name = 'r_skewing1_obs_err'; format = 'E'
#     name = 'r_shift3_obs_err'; format = 'E'
#     name = 'r_shift8_obs'; format = 'E'
#     name = 'r_skewing4_obs_mag'; format = 'E'
#     name = 'r_shift6_obs_mag'; format = 'E'
#     name = 'r_shift4_obs_err'; format = 'E'
#     name = 'r_softening4_obs'; format = 'E'
#     name = 'r_shift1_obs_mag_err'; format = 'E'
#     name = 'r_shift5_obs_mag_err'; format = 'E'
#     name = 'r_skewing4_obs_err'; format = 'E'
#     name = 'r_skewing0_obs_err'; format = 'E'
#     name = 'r_shift9_obs_mag_err'; format = 'E'
#     name = 'r_skewing4_obs'; format = 'E'
#     name = 'r_shift9_obs'; format = 'E'
#     name = 'J_obs'; format = 'E'
#     name = 'r_shift9_obs_mag'; format = 'E'
#     name = 'r_softening8_obs_mag'; format = 'E'
#     name = 'r_shift5_obs_mag'; format = 'E'
#     name = 'r_softening4_obs_err'; format = 'E'
#     name = 'r_widening7_obs_err'; format = 'E'
#     name = 'r_widening9_obs_mag_err'; format = 'E'
#     name = 'H_obs_err'; format = 'E'
#     name = 'r_widening9_obs_mag'; format = 'E'
#     name = 'z_obs_mag_err'; format = 'E'
#     name = 'r_obs_mag'; format = 'E'
#     name = 'vis_obs'; format = 'E'
#     name = 'Y_obs_err'; format = 'E'
#     name = 'z_obs'; format = 'E'
#     name = 'Y_obs_mag_err'; format = 'E'
#     name = 'r_softening2_obs'; format = 'E'
#     name = 'r_shift4_obs'; format = 'E'
#     name = 'u_obs_err'; format = 'E'
#     name = 'r_softening3_obs'; format = 'E'
#     name = 'r_softening6_obs_mag_err'; format = 'E'
#     name = 'r_shift6_obs_err'; format = 'E'
#     name = 'r_skewing9_obs_mag'; format = 'E'
#     name = 'r_shift4_obs_mag_err'; format = 'E'
#     name = 'vis_obs_mag'; format = 'E'
#     name = 'r_shift3_obs_mag_err'; format = 'E'
#     name = 'r_widening4_obs_err'; format = 'E'
#     name = 'r_shift1_obs_mag'; format = 'E'
#     name = 'J_obs_err'; format = 'E'
#     name = 'H_obs'; format = 'E'
#     name = 'r_softening1_obs_err'; format = 'E'
#     name = 'r_softening2_obs_mag'; format = 'E'
#     name = 'r_shift8_obs_mag'; format = 'E'
#     name = 'r_shift2_obs_mag_err'; format = 'E'
#     name = 'u_obs_mag'; format = 'E'
#     name = 'g_obs_mag_err'; format = 'E'
#     name = 'r_shift2_obs_mag'; format = 'E'
#     name = 'Y_obs'; format = 'E'
#     name = 'z_obs_err'; format = 'E'
#     name = 'r_softening9_obs_mag'; format = 'E'
#     name = 'r_skewing5_obs'; format = 'E'
#     name = 'r_shift3_obs'; format = 'E'
#     name = 'r_widening4_obs_mag'; format = 'E'
#     name = 'J_obs_mag'; format = 'E'
#     name = 'r_widening1_obs'; format = 'E'
#     name = 'r_widening0_obs'; format = 'E'
#     name = 'r_shift5_obs'; format = 'E'
#     name = 'r_softening9_obs_mag_err'; format = 'E'
#     name = 'r_shift4_obs_mag'; format = 'E'
#     name = 'u_obs'; format = 'E'
#     name = 'r_shift0_obs_mag'; format = 'E'
#     name = 'r_skewing2_obs_mag'; format = 'E'
#     name = 'r_widening3_obs_err'; format = 'E'
#     name = 'vis_obs_err'; format = 'E'
#     name = 'r_widening1_obs_mag_err'; format = 'E'
#     name = 'r_shift7_obs_err'; format = 'E'
#     name = 'r_shift2_obs'; format = 'E'
#     name = 'r_skewing7_obs_mag_err'; format = 'E'
#     name = 'r_widening5_obs'; format = 'E'
#     name = 'r_softening7_obs_mag'; format = 'E'
#     name = 'r_widening9_obs_err'; format = 'E'
#     name = 'r_shift7_obs_mag'; format = 'E'
#     name = 'r_widening1_obs_mag'; format = 'E'
#     name = 'r_skewing2_obs_mag_err'; format = 'E'
#     name = 'r_softening2_obs_err'; format = 'E'
#     name = 'r_widening7_obs'; format = 'E'
#     name = 'i_obs_err'; format = 'E'
#     name = 'r_skewing5_obs_mag_err'; format = 'E'
#     name = 'r_widening7_obs_mag_err'; format = 'E'
#     name = 'r_skewing2_obs'; format = 'E'
#     name = 'r_skewing3_obs_mag'; format = 'E'
#     name = 'r_skewing9_obs_mag_err'; format = 'E'
#     name = 'r_skewing6_obs'; format = 'E'
#     name = 'r_widening0_obs_mag_err'; format = 'E'
#     name = 'r_softening8_obs'; format = 'E'
#     name = 'r_shift1_obs'; format = 'E'
#     name = 'r_obs_mag_err'; format = 'E'
#     name = 'r_softening7_obs'; format = 'E'
# )

# %% [markdown]
# An example of what I was saying. So, for instance, for `r_shift0`, the mean wavelength of the filter tranmission:

# %%
mean_r_shift0 = np.average(fluxes['r_shift0'].data['Wavelength'], weights=fluxes['r_shift0'].data['Transmission'])
print(mean_r_shift0)
# Out:
# 6199.88

# %%
mean_r = np.average(fluxes['r'].data['Wavelength'], weights=fluxes['r'].data['Transmission'])
print(mean_r)
# Out:
# 6299.88

# %%
# So the shift if
mean_r_shift0 - mean_r
# Out:
# -100.0

# %%
# Just for fun
for i in range(10):
    name = f'r_shift{i}'
    transmission = fluxes[name].data
    mean_shifted = np.average(transmission['Wavelength'], weights=transmission['Transmission'])
    print(f'{name} shifted {mean_shifted-mean_r}')
# Out:
# r_shift0 shifted -100.0
# r_shift1 shifted -77.77783203125
# r_shift2 shifted -55.5556640625
# r_shift3 shifted -33.33349609375
# r_shift4 shifted -11.11083984375
# r_shift5 shifted 11.111328125
# r_shift6 shifted 33.33349609375
# r_shift7 shifted 55.5556640625
# r_shift8 shifted 77.77783203125
# r_shift9 shifted 100.00048828125

# %% [markdown]
# In the usual ph2ref repo there is now a script called [`add-filter-means-wavelength.py`](https://gitlab.astro.unige.ch/aalvarez/ph2ref/blob/master/add-filter-means-wavelength.py) to do this.
#
# Here is a sample of the output catalog

# %%
with_filter_means = Table.read('/home/aalvarez/Work/Data/coupon/fluxes_COSMOS15_test_with_means.fits')
with_filter_means.colnames
# Out:
# ['ID',
#  'u',
#  'g',
#  'r',
#  'i',
#  'z',
#  'vis',
#  'Y',
#  'J',
#  'H',
#  'r_shift0',
#  'r_shift1',
#  'r_shift2',
#  'r_shift3',
#  'r_shift4',
#  'r_shift5',
#  'r_shift6',
#  'r_shift7',
#  'r_shift8',
#  'r_shift9',
#  'r_widening0',
#  'r_widening1',
#  'r_widening2',
#  'r_widening3',
#  'r_widening4',
#  'r_widening5',
#  'r_widening6',
#  'r_widening7',
#  'r_widening8',
#  'r_widening9',
#  'r_skewing0',
#  'r_skewing1',
#  'r_skewing2',
#  'r_skewing3',
#  'r_skewing4',
#  'r_skewing5',
#  'r_skewing6',
#  'r_skewing7',
#  'r_skewing8',
#  'r_skewing9',
#  'r_softening0',
#  'r_softening1',
#  'r_softening2',
#  'r_softening3',
#  'r_softening4',
#  'r_softening5',
#  'r_softening6',
#  'r_softening7',
#  'r_softening8',
#  'r_softening9',
#  'ra',
#  'dec',
#  'z_true',
#  'has_spec_z',
#  'weight',
#  'radius',
#  'r_shift7_obs_mag_err',
#  'r_widening8_obs_mag',
#  'r_skewing9_obs_err',
#  'r_softening1_obs_mag',
#  'r_softening5_obs',
#  'r_softening8_obs_err',
#  'r_skewing3_obs_mag_err',
#  'r_shift0_obs_mag_err',
#  'r_softening9_obs_err',
#  'r_skewing8_obs_err',
#  'r_shift1_obs_err',
#  'r_skewing0_obs',
#  'r_shift9_obs_err',
#  'r_skewing6_obs_mag',
#  'i_obs_mag',
#  'r_widening0_obs_err',
#  'r_softening0_obs',
#  'r_widening7_obs_mag',
#  'r_skewing5_obs_mag',
#  'J_obs_mag_err',
#  'i_obs',
#  'r_softening1_obs',
#  'r_skewing8_obs_mag',
#  'r_softening4_obs_mag_err',
#  'z_obs_mag',
#  'r_widening6_obs_mag_err',
#  'r_softening5_obs_err',
#  'r_skewing1_obs',
#  'r_shift3_obs_mag',
#  'r_widening8_obs_mag_err',
#  'r_widening3_obs_mag',
#  'r_widening3_obs_mag_err',
#  'r_skewing2_obs_err',
#  'r_softening4_obs_mag',
#  'r_widening6_obs_mag',
#  'r_skewing6_obs_err',
#  'r_softening3_obs_err',
#  'r_widening8_obs',
#  'r_skewing4_obs_mag_err',
#  'r_softening0_obs_mag',
#  'r_shift0_obs',
#  'Y_obs_mag',
#  'r_skewing5_obs_err',
#  'r_shift6_obs_mag_err',
#  'g_obs_mag',
#  'r_skewing1_obs_mag',
#  'r_softening0_obs_mag_err',
#  'g_obs',
#  'r_softening1_obs_mag_err',
#  'u_obs_mag_err',
#  'r_shift7_obs',
#  'r_widening4_obs_mag_err',
#  'i_obs_mag_err',
#  'r_obs',
#  'r_obs_err',
#  'r_widening0_obs_mag',
#  'r_widening6_obs_err',
#  'r_softening5_obs_mag',
#  'r_widening5_obs_mag',
#  'r_softening5_obs_mag_err',
#  'r_softening7_obs_err',
#  'r_widening5_obs_err',
#  'r_skewing7_obs_err',
#  'r_widening4_obs',
#  'r_softening6_obs_err',
#  'H_obs_mag',
#  'r_widening6_obs',
#  'g_obs_err',
#  'r_softening8_obs_mag_err',
#  'r_skewing0_obs_mag',
#  'r_widening5_obs_mag_err',
#  'r_softening2_obs_mag_err',
#  'H_obs_mag_err',
#  'r_widening9_obs',
#  'r_skewing1_obs_mag_err',
#  'r_softening6_obs_mag',
#  'r_skewing9_obs',
#  'r_shift0_obs_err',
#  'vis_obs_mag_err',
#  'r_shift5_obs_err',
#  'r_widening2_obs_err',
#  'r_widening8_obs_err',
#  'r_skewing8_obs_mag_err',
#  'r_widening3_obs',
#  'r_skewing6_obs_mag_err',
#  'r_softening9_obs',
#  'r_skewing3_obs_err',
#  'r_skewing0_obs_mag_err',
#  'r_shift8_obs_mag_err',
#  'r_widening1_obs_err',
#  'r_widening2_obs_mag_err',
#  'r_softening6_obs',
#  'r_widening2_obs',
#  'r_shift8_obs_err',
#  'r_widening2_obs_mag',
#  'r_skewing8_obs',
#  'r_softening3_obs_mag',
#  'r_skewing3_obs',
#  'r_shift2_obs_err',
#  'r_skewing7_obs',
#  'r_skewing7_obs_mag',
#  'r_softening0_obs_err',
#  'r_softening7_obs_mag_err',
#  'r_shift6_obs',
#  'r_softening3_obs_mag_err',
#  'r_skewing1_obs_err',
#  'r_shift3_obs_err',
#  'r_shift8_obs',
#  'r_skewing4_obs_mag',
#  'r_shift6_obs_mag',
#  'r_shift4_obs_err',
#  'r_softening4_obs',
#  'r_shift1_obs_mag_err',
#  'r_shift5_obs_mag_err',
#  'r_skewing4_obs_err',
#  'r_skewing0_obs_err',
#  'r_shift9_obs_mag_err',
#  'r_skewing4_obs',
#  'r_shift9_obs',
#  'J_obs',
#  'r_shift9_obs_mag',
#  'r_softening8_obs_mag',
#  'r_shift5_obs_mag',
#  'r_softening4_obs_err',
#  'r_widening7_obs_err',
#  'r_widening9_obs_mag_err',
#  'H_obs_err',
#  'r_widening9_obs_mag',
#  'z_obs_mag_err',
#  'r_obs_mag',
#  'vis_obs',
#  'Y_obs_err',
#  'z_obs',
#  'Y_obs_mag_err',
#  'r_softening2_obs',
#  'r_shift4_obs',
#  'u_obs_err',
#  'r_softening3_obs',
#  'r_softening6_obs_mag_err',
#  'r_shift6_obs_err',
#  'r_skewing9_obs_mag',
#  'r_shift4_obs_mag_err',
#  'vis_obs_mag',
#  'r_shift3_obs_mag_err',
#  'r_widening4_obs_err',
#  'r_shift1_obs_mag',
#  'J_obs_err',
#  'H_obs',
#  'r_softening1_obs_err',
#  'r_softening2_obs_mag',
#  'r_shift8_obs_mag',
#  'r_shift2_obs_mag_err',
#  'u_obs_mag',
#  'g_obs_mag_err',
#  'r_shift2_obs_mag',
#  'Y_obs',
#  'z_obs_err',
#  'r_softening9_obs_mag',
#  'r_skewing5_obs',
#  'r_shift3_obs',
#  'r_widening4_obs_mag',
#  'J_obs_mag',
#  'r_widening1_obs',
#  'r_widening0_obs',
#  'r_shift5_obs',
#  'r_softening9_obs_mag_err',
#  'r_shift4_obs_mag',
#  'u_obs',
#  'r_shift0_obs_mag',
#  'r_skewing2_obs_mag',
#  'r_widening3_obs_err',
#  'vis_obs_err',
#  'r_widening1_obs_mag_err',
#  'r_shift7_obs_err',
#  'r_shift2_obs',
#  'r_skewing7_obs_mag_err',
#  'r_widening5_obs',
#  'r_softening7_obs_mag',
#  'r_widening9_obs_err',
#  'r_shift7_obs_mag',
#  'r_widening1_obs_mag',
#  'r_skewing2_obs_mag_err',
#  'r_softening2_obs_err',
#  'r_widening7_obs',
#  'i_obs_err',
#  'r_skewing5_obs_mag_err',
#  'r_widening7_obs_mag_err',
#  'r_skewing2_obs',
#  'r_skewing3_obs_mag',
#  'r_skewing9_obs_mag_err',
#  'r_skewing6_obs',
#  'r_widening0_obs_mag_err',
#  'r_softening8_obs',
#  'r_shift1_obs',
#  'r_obs_mag_err',
#  'r_softening7_obs',
#  'r_shift0_mean',
#  'r_shift1_mean',
#  'r_shift2_mean',
#  'r_shift3_mean',
#  'r_shift4_mean',
#  'r_shift5_mean',
#  'r_shift6_mean',
#  'r_shift7_mean',
#  'r_shift8_mean',
#  'r_shift9_mean',
#  'r_widening0_mean',
#  'r_widening1_mean',
#  'r_widening2_mean',
#  'r_widening3_mean',
#  'r_widening4_mean',
#  'r_widening5_mean',
#  'r_widening6_mean',
#  'r_widening7_mean',
#  'r_widening8_mean',
#  'r_widening9_mean',
#  'r_skewing0_mean',
#  'r_skewing1_mean',
#  'r_skewing2_mean',
#  'r_skewing3_mean',
#  'r_skewing4_mean',
#  'r_skewing5_mean',
#  'r_skewing6_mean',
#  'r_skewing7_mean',
#  'r_skewing8_mean',
#  'r_skewing9_mean',
#  'r_softening0_mean',
#  'r_softening1_mean',
#  'r_softening2_mean',
#  'r_softening3_mean',
#  'r_softening4_mean',
#  'r_softening5_mean',
#  'r_softening6_mean',
#  'r_softening7_mean',
#  'r_softening8_mean',
#  'r_softening9_mean']

# %%
with_filter_means[:5]['r', 'r_shift0', 'r_shift0_mean']
# Out:
# <Table masked=True length=5>
#     r      r_shift0 r_shift0_mean
#  float32   float32     float32
# --------- --------- -------------
#   6.00605   5.81869       6199.88
#   42.6332   39.9572       6199.88
#   226.256   213.619       6199.88
#  0.177467  0.177353       6199.88
# 0.0383894 0.0380675       6199.88

# %% [markdown]
# Ok, so now should run `nnpz` over this catalog, using `r` without the means, and the modified `r` with the means.
# Could do it manually, but...

# %%
from IPython.display import Image
Image(filename='/home/aalvarez/Pictures/meh.jpg')

# %% [markdown]
# We can script its execution, generating a config file on the fly for each possible combination.
# We can do the analysis later on this notebook.
