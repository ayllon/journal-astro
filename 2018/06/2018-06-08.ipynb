# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from astropy.table import Table

# %%
chi2 = Table.read('/tmp/nnpz_compare/r_shift9/n_real_ac7e629e362cdda7b479c74222ad2c81.fits')
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
def plot_distance_vs_weight(distances, weights, marker=None):
    sorted_index = np.flip(distances.argsort(), axis=0)
    plt.plot(distances[sorted_index], weights[sorted_index], marker=marker)

# %%
plt.figure()
#plot_distance_vs_weight(chi2['NeighborDistances'].flatten(), chi2['NeighborWeights'].flatten())
plot_distance_vs_weight(chi2['NeighborDistances'][4], chi2['NeighborWeights'][4], 'x')
plot_distance_vs_weight(chi2['NeighborDistances'][0], chi2['NeighborWeights'][0], '.')
plot_distance_vs_weight(chi2['NeighborDistances'][1760], chi2['NeighborWeights'][1760], '^')
plot_distance_vs_weight(chi2['NeighborDistances'][3], chi2['NeighborWeights'][3], '<')
plot_distance_vs_weight(chi2['NeighborDistances'][2], chi2['NeighborWeights'][2], '>')

plt.xlabel('$Distance\ \chi^2$')
plt.ylabel('$Weight\ likelihood$')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'$Weight\\ likelihood$')

# %%
euclidean = Table.read('/tmp/nnpz_compare/r_shift9/n_kdtree_6dfc931e5313a239f7a4c4e000099857.fits')
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
plt.figure()
plot_distance_vs_weight(euclidean['NeighborDistances'][874], euclidean['NeighborWeights'][874], 'x')
#plot_distance_vs_weight(euclidean['NeighborDistances'][0], euclidean['NeighborWeights'][0], '.')
#plot_distance_vs_weight(euclidean['NeighborDistances'].flatten(), euclidean['NeighborWeights'].flatten())
#plot_distance_vs_weight(euclidean['NeighborDistances'][4], euclidean['NeighborWeights'][4], 'x')

#plot_distance_vs_weight(euclidean['NeighborDistances'][1760], euclidean['NeighborWeights'][1760], '^')
#plot_distance_vs_weight(euclidean['NeighborDistances'][3], euclidean['NeighborWeights'][3], '<')
plot_distance_vs_weight(euclidean['NeighborDistances'][2], euclidean['NeighborWeights'][2], '>')

plt.xlabel('$d$')
plt.ylabel('$Weight\ 1/d$')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'$Weight\\ 1/d$')
