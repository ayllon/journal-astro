# %%
# %matplotlib inline
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
perf = pandas.read_csv('/tmp/perf.csv', index_col='Method')
perf
# Out:
#         Arguments           1           2            3            4  \
# Method
# Python          2    74883.01     61198.3     57726.65     63033.68
# Pyston          2  6580020.95  12237760.1  15084639.91  28885663.32
#
#                   5            6            7            8  Unnamed: 10
# Method
# Python     67141.17     69589.46     68544.55     67097.14          NaN
# Pyston  20707809.49  24571694.88  27210947.82  32666474.48          NaN

# %%
del perf['Arguments']

# %%
perf.transpose().plot(figsize=(20, 10))
plt.ylabel('Calls / second')
plt.xlabel('Threads')
plt.show()
