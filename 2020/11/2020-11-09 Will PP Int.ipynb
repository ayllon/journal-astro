# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
from astropy.table import Table, Column, join

plt.rcParams['figure.figsize'] = (20, 10)

# %%
hdul = fits.open('/home/aalvarez/Work/Data/WillPP/TargetPP.fits')
t = Table(hdul[1].data)

# %%
obj = t[15]

fig, axes = plt.subplots(ncols=2)

axes[0].bar(hdul['BINS_MC_COUNT_SFH_TYPE'].data['BINS'], obj['MC_COUNT_SFH_TYPE'])
axes[0].set_title('SFH TYPE')
axes[0].set_xticks(hdul['BINS_MC_COUNT_SFH_TYPE'].data['BINS'])

axes[1].bar(
    hdul['BINS_MC_SLICE_AGGREGATE_SFH_TAU_SFH_TYPE_AVG'].data['SFH_TYPE'][:-1]+0.5,
    obj['MC_SLICE_AGGREGATE_SFH_TAU_SFH_TYPE_AVG']
)
axes[1].set_xticks(hdul['BINS_MC_COUNT_SFH_TYPE'].data['BINS'])

plt.tight_layout()
