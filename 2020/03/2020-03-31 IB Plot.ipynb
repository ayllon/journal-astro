# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
sys.path.append('/home/aalvarez/Work/Projects/Elements/5.8/InstallArea/x86_64-fc31-gcc92-dbg/python/')
sys.path.append('/home/aalvarez/Work/Projects/PHZ_NNPZ/PHZ_NNPZ/NNPZ/python/')
os.environ['ELEMENTS_AUX_PATH'] = '/home/aalvarez/Work/Projects/PHZ_NNPZ/PHZ_NNPZ/NNPZ/auxdir/'
os.environ['PATH'] = os.environ['PATH'] + ':/home/aalvarez/Work/Projects/PHZ_NNPZ/PHZ_NNPZ/build.x86_64-fc31-gcc92-dbg/scripts/'

# %%
from nnpz.photometry import *

# %%
euclid_filter_provider = DirectoryFilterProvider('/home/aalvarez/Phosphoros/AuxiliaryData/Filters/SC456/')
euclid_filter_names = ['VIS', 'H', 'J', 'Y', 'lsst_u', 'lsst_g', 'lsst_r', 'lsst_i', 'lsst_z']
subaru_filter_provider = DirectoryFilterProvider('/home/aalvarez/Phosphoros/AuxiliaryData/Filters/Subaru/')
subaru_filter_names = subaru_filter_provider.getFilterNames()

# %%
plt.figure(figsize=(20, 10))
for f in euclid_filter_names:
    t = euclid_filter_provider.getFilterTransmission(f)
    plt.plot(t[:,0], t[:,1], ':', c='gray')
for f in subaru_filter_names:
    t = subaru_filter_provider.getFilterTransmission(f)
    plt.plot(t[:,0], t[:,1], label=f.split('.')[0])
plt.xlabel('$\lambda$')
plt.legend()
plt.show()
